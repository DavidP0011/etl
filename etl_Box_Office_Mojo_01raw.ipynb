# %%
# Instalación de bibliotecas necesarias
# !pip install requests beautifulsoup4 pandas google-cloud-bigquery

import requests
from bs4 import BeautifulSoup
import pandas as pd
from google.cloud import bigquery
import re
import time
import logging
from datetime import datetime

def scrape_and_upload_with_tconst(config):
    """
    Función para scrapear datos de Box Office Mojo y agregar el tconst desde IMDb Pro,
    luego subir los datos a Google BigQuery.

    Args:
        config (dict): Configuración de la función.
            - "project_id" (str): ID del proyecto en Google Cloud.
            - "dataset_id" (str): ID del conjunto de datos en BigQuery.
            - "table_id" (str): Nombre de la tabla en BigQuery.
            - "start_year" (int): Año inicial del rango.
            - "end_year" (int): Año final del rango.
            - "truncate_table" (bool): Si es True, truncar la tabla antes de subir los datos.
            - "log_file" (str): Ruta al archivo de log (opcional).
    """
    # Configuración del logger
    logger = logging.getLogger('BoxOfficeScraper')
    logger.setLevel(logging.DEBUG)  # Establece el nivel mínimo de log

    # Crear manejador para consola
    ch = logging.StreamHandler()
    ch.setLevel(logging.INFO)  # Nivel de log para la consola

    # Crear manejador para archivo (si se especifica)
    if 'log_file' in config:
        fh = logging.FileHandler(config['log_file'])
        fh.setLevel(logging.DEBUG)  # Nivel de log para el archivo
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        fh.setFormatter(formatter)
        logger.addHandler(fh)

    # Formateador para la consola
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    ch.setFormatter(formatter)

    # Añadir manejadores al logger
    logger.addHandler(ch)

    # Configuración del cliente BigQuery
    client = bigquery.Client(project=config["project_id"])

    # Función interna para scrapeo de la tabla principal
    def scrape_box_office(year):
        url = f"https://www.boxofficemojo.com/year/world/{year}/"
        logger.info(f"Accediendo a la URL: {url}")
        try:
            response = requests.get(url)
            response.raise_for_status()
            logger.debug(f"Respuesta HTTP obtenida para el año {year}.")
        except requests.exceptions.RequestException as e:
            logger.error(f"Error al acceder a la página para el año {year}: {e}")
            return pd.DataFrame()

        soup = BeautifulSoup(response.content, "html.parser")

        # Buscar la tabla principal
        table = soup.find("table")
        if not table:
            logger.warning(f"No se encontró la tabla para el año {year}.")
            return pd.DataFrame()

        # Extraer encabezados para mapear columnas dinámicamente
        headers = [header.text.strip() for header in table.find_all("th")]
        logger.debug(f"Encabezados de la tabla para {year}: {headers}")

        # Mapeo de columnas basado en los encabezados actuales
        try:
            rank_idx = headers.index("Rank")
            title_idx = headers.index("Release Group")
            worldwide_gross_idx = headers.index("Worldwide")
            domestic_gross_idx = headers.index("Domestic")
            international_gross_idx = headers.index("Foreign")
        except ValueError as ve:
            logger.error(f"Error al encontrar índices de columnas: {ve}")
            return pd.DataFrame()

        rows = table.find_all("tr")[1:]  # Ignorar el encabezado

        # Procesar filas
        data = []
        total_rows = len(rows)
        logger.info(f"Procesando {total_rows} filas para el año {year}...")
        for idx, row in enumerate(rows, start=1):
            cols = row.find_all("td")
            if len(cols) < max(rank_idx, title_idx, worldwide_gross_idx, domestic_gross_idx, international_gross_idx) + 1:
                logger.debug(f"Fila {idx} ignorada por tener columnas insuficientes.")
                continue

            # Verificar si la primera columna es un número (Rank)
            rank_text = cols[rank_idx].text.strip()
            if not rank_text.isdigit():
                logger.debug(f"Fila {idx} ignorada porque 'Rank' no es un número: '{rank_text}'")
                continue  # Saltar filas donde el Rank no es un número

            try:
                rank = int(rank_text)
                title = cols[title_idx].text.strip()
                title_link = cols[title_idx].find("a")["href"]

                # Función interna para parsear valores de ganancias
                def parse_gross(text):
                    text = text.strip().replace("$", "").replace(",", "").replace("--", "").replace("-", "")
                    if text in ["", "--", "-"]:
                        return None
                    # Manejar posibles rangos o valores no numéricos
                    match = re.match(r'^\d+$', text)
                    return int(text) if match else None

                # Extraer y parsear las ganancias
                domestic_text = cols[domestic_gross_idx].text.strip()
                foreign_text = cols[international_gross_idx].text.strip()
                logger.debug(f"Fila {idx}: Domestic='{domestic_text}', Foreign='{foreign_text}'")

                worldwide_gross = parse_gross(cols[worldwide_gross_idx].text)
                domestic_gross = parse_gross(domestic_text)
                international_gross = parse_gross(foreign_text)

                # Agregar los datos al listado
                data.append({
                    "Year": year,
                    "Rank": rank,
                    "Title": title,
                    "Worldwide_Gross": worldwide_gross,
                    "Domestic_Gross": domestic_gross,
                    "International_Gross": international_gross,
                    "Detail_Link": f"https://www.boxofficemojo.com{title_link}"
                })
            except Exception as e:
                logger.error(f"Error procesando una fila en el índice {idx}: {e}")
                continue

            # Añadir retraso entre filas para evitar sobrecargar el servidor
            time.sleep(0.1)  # Esperar 100ms

        logger.info(f"Procesadas {len(data)} filas válidas para el año {year}.")
        return pd.DataFrame(data)

    # Función interna para obtener el tconst de IMDb Pro desde la página de detalles
    def get_tconst(detail_link):
        logger.debug(f"Obteniendo tconst desde: {detail_link}")
        try:
            response = requests.get(detail_link)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")

            # Buscar el enlace a IMDb Pro
            imdb_link = soup.find("a", href=lambda href: href and "pro.imdb.com/title" in href)
            if imdb_link:
                tconst_match = re.search(r'/title/(tt\d+)/', imdb_link["href"])
                if tconst_match:
                    tconst = tconst_match.group(1)
                    logger.debug(f"tconst encontrado: {tconst}")
                    return tconst
            logger.warning(f"tconst no encontrado en: {detail_link}")
        except requests.exceptions.RequestException as e:
            logger.error(f"Error al acceder al detalle: {detail_link} - {e}")
        except Exception as e:
            logger.error(f"Error al procesar el detalle: {detail_link} - {e}")
        return None

    # Scrapear datos para cada año en el rango
    all_data = pd.DataFrame()
    for year in range(config["start_year"], config["end_year"] + 1):
        logger.info(f"Scraping data for {year}...")
        year_data = scrape_box_office(year)

        if year_data.empty:
            logger.warning(f"No se encontraron datos para el año {year}.")
            continue

        # Agregar tconst a cada fila
        logger.info("Fetching IMDb tconst for each title...")
        year_data["tconst"] = year_data["Detail_Link"].apply(get_tconst)

        # Reportar cuántos tconst se encontraron
        tconst_found = year_data["tconst"].notnull().sum()
        tconst_total = len(year_data)
        logger.info(f"tconst encontrados: {tconst_found}/{tconst_total}")

        all_data = pd.concat([all_data, year_data], ignore_index=True)

    if all_data.empty:
        logger.error("No hay datos para subir a BigQuery.")
        return

    # Definir el esquema de BigQuery
    schema = [
        bigquery.SchemaField("Year", "INTEGER"),
        bigquery.SchemaField("Rank", "INTEGER"),
        bigquery.SchemaField("Title", "STRING"),
        bigquery.SchemaField("Worldwide_Gross", "INTEGER"),
        bigquery.SchemaField("Domestic_Gross", "INTEGER"),
        bigquery.SchemaField("International_Gross", "INTEGER"),
        bigquery.SchemaField("Detail_Link", "STRING"),
        bigquery.SchemaField("tconst", "STRING"),
    ]

    # Convertir las columnas de ganancias a tipo integer (ya se hizo en parse_gross)
    # Verificar tipos de datos
    expected_types = {
        "Year": int,
        "Rank": int,
        "Title": str,
        "Worldwide_Gross": pd.Int64Dtype(),
        "Domestic_Gross": pd.Int64Dtype(),
        "International_Gross": pd.Int64Dtype(),
        "Detail_Link": str,
        "tconst": str,
    }

    for column, dtype in expected_types.items():
        if column in all_data.columns:
            all_data[column] = all_data[column].astype(dtype)
        else:
            all_data[column] = None  # Agregar columna si falta

    # Registro de datos para depuración
    logger.info("Vista previa de los datos recopilados:")
    logger.debug(all_data.head())

    logger.info("Resumen de valores nulos:")
    logger.debug(all_data.isnull().sum())

    # Subir datos a BigQuery con esquema definido
    table_id = f"{config['project_id']}.{config['dataset_id']}.{config['table_id']}"
    logger.info(f"Uploading data to BigQuery table: {table_id}...")

    job_config = bigquery.LoadJobConfig(
        schema=schema,
        write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE if config.get("truncate_table", False) else bigquery.WriteDisposition.WRITE_APPEND,
        source_format=bigquery.SourceFormat.PARQUET,
    )

    try:
        job = client.load_table_from_dataframe(all_data, table_id, job_config=job_config)
        job.result()  # Esperar a que termine el trabajo
        logger.info("Datos subidos exitosamente!")
        logger.info(f"Total de registros cargados: {len(all_data)}")
    except Exception as e:
        logger.error(f"Error al subir datos a BigQuery: {e}")

# %%
# Configuración de ejemplo
config = {
    "project_id": "animum-dev-datawarehouse",   # Cambia esto por tu ID de proyecto
    "dataset_id": "BOMojo_staging_01",   # Cambia esto por tu ID de dataset
    "table_id": "WorldwideBoxOffice_01",         # Cambia esto por el nombre de la tabla
    "start_year": 2000,                # Año inicial del rango
    "end_year": 2024,                   # Año final del rango
    "delete_table": True               # True para borrar los registros la tabla antes de cargar los datos
}

# Ejecutar función
scrape_and_upload_with_tconst(config)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# DEBUG:BoxOfficeScraper:tconst encontrado: tt5769516
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr554717701/?ref_=bo_ydw_table_178
# DEBUG:BoxOfficeScraper:tconst encontrado: tt2547584
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3975041541/?ref_=bo_ydw_table_179
# DEBUG:BoxOfficeScraper:tconst encontrado: tt2800050
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3188019717/?ref_=bo_ydw_table_180
# DEBUG:BoxOfficeScraper:tconst encontrado: tt6167014
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2533839365/?ref_=bo_ydw_table_181
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4629266
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2244235781/?ref_=bo_ydw_table_182
# DEBUG:BoxOfficeScraper:tconst encontrado: tt3499096
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr569004549/?ref_=bo_ydw_table_183
# DEBUG:BoxOfficeScraper:tconst encontrado: tt5842624
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr241127941/?ref_=bo_ydw_table_184
# DEBUG:BoxOfficeScraper:tconst encontrado: tt1124037
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2211074565/?ref_=bo_ydw_table_185
# DEBUG:BoxOfficeScraper:tconst encontrado: tt3553442
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3407696389/?ref_=bo_ydw_table_186
# DEBUG:BoxOfficeScraper:tconst encontrado: tt6054290
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr520573445/?ref_=bo_ydw_table_187
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4685554
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr1869697541/?ref_=bo_ydw_table_188
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4824308
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr4191244805/?ref_=bo_ydw_table_189
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4979860
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2868597253/?ref_=bo_ydw_table_190
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4276820
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr1223250437/?ref_=bo_ydw_table_191
# DEBUG:BoxOfficeScraper:tconst encontrado: tt1798603
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3894891013/?ref_=bo_ydw_table_192
# DEBUG:BoxOfficeScraper:tconst encontrado: tt5503266
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2770686469/?ref_=bo_ydw_table_193
# DEBUG:BoxOfficeScraper:tconst encontrado: tt0490215
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr1883722245/?ref_=bo_ydw_table_194
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4669186
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3171111429/?ref_=bo_ydw_table_195
# DEBUG:BoxOfficeScraper:tconst encontrado: tt5259966
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr275862021/?ref_=bo_ydw_table_196
# DEBUG:BoxOfficeScraper:tconst encontrado: tt4981636
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2661896709/?ref_=bo_ydw_table_197
# DEBUG:BoxOfficeScraper:tconst encontrado: tt1712261
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2824819205/?ref_=bo_ydw_table_198
# DEBUG:BoxOfficeScraper:tconst encontrado: tt2822672
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3930280453/?ref_=bo_ydw_table_199
# DEBUG:BoxOfficeScraper:tconst encontrado: tt3797868
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr857756165/?ref_=bo_ydw_table_200
# DEBUG:BoxOfficeScraper:tconst encontrado: tt5253294
# 2025-01-05 19:55:15,689 - INFO - tconst encontrados: 200/200
# INFO:BoxOfficeScraper:tconst encontrados: 200/200
# 2025-01-05 19:55:15,698 - INFO - Scraping data for 2017...
# INFO:BoxOfficeScraper:Scraping data for 2017...
# 2025-01-05 19:55:15,702 - INFO - Accediendo a la URL: https://www.boxofficemojo.com/year/world/2017/
# INFO:BoxOfficeScraper:Accediendo a la URL: https://www.boxofficemojo.com/year/world/2017/
# DEBUG:BoxOfficeScraper:Respuesta HTTP obtenida para el año 2017.
# DEBUG:BoxOfficeScraper:Encabezados de la tabla para 2017: ['Rank', 'Release Group', 'Worldwide', 'Domestic', '%', 'Foreign', '%']
# 2025-01-05 19:55:18,669 - INFO - Procesando 200 filas para el año 2017...
# INFO:BoxOfficeScraper:Procesando 200 filas para el año 2017...
# DEBUG:BoxOfficeScraper:Fila 1: Domestic='$620,181,382', Foreign='$712,358,507'
# DEBUG:BoxOfficeScraper:Fila 2: Domestic='$504,014,165', Foreign='$759,506,961'
# DEBUG:BoxOfficeScraper:Fila 3: Domestic='$226,008,385', Foreign='$1,009,996,733'
# DEBUG:BoxOfficeScraper:Fila 4: Domestic='$264,624,300', Foreign='$770,175,109'
# DEBUG:BoxOfficeScraper:Fila 5: Domestic='$404,515,480', Foreign='$557,562,066'
# DEBUG:BoxOfficeScraper:Fila 6: Domestic='$334,201,140', Foreign='$545,965,784'
# DEBUG:BoxOfficeScraper:Fila 7: Domestic='$2,721,100', Foreign='$867,604,339'
# DEBUG:BoxOfficeScraper:Fila 8: Domestic='$389,813,101', Foreign='$473,942,950'
# DEBUG:BoxOfficeScraper:Fila 9: Domestic='$315,058,289', Foreign='$538,918,837'
# DEBUG:BoxOfficeScraper:Fila 10: Domestic='$412,563,408', Foreign='$410,400,000'
# DEBUG:BoxOfficeScraper:Fila 11: Domestic='$210,460,015', Foreign='$604,181,157'
# DEBUG:BoxOfficeScraper:Fila 12: Domestic='$172,558,876', Foreign='$622,302,918'
# DEBUG:BoxOfficeScraper:Fila 13: Domestic='$327,481,748', Foreign='$375,300,000'
# DEBUG:BoxOfficeScraper:Fila 14: Domestic='$229,024,295', Foreign='$432,300,000'
# DEBUG:BoxOfficeScraper:Fila 15: Domestic='$226,277,068', Foreign='$392,744,368'
# DEBUG:BoxOfficeScraper:Fila 16: Domestic='$130,168,683', Foreign='$475,256,474'
# DEBUG:BoxOfficeScraper:Fila 17: Domestic='$168,052,812', Foreign='$400,600,000'
# DEBUG:BoxOfficeScraper:Fila 18: Domestic='$175,003,033', Foreign='$352,962,903'
# DEBUG:BoxOfficeScraper:Fila 19: Domestic='$188,045,546', Foreign='$338,000,000'
# DEBUG:BoxOfficeScraper:Fila 20: Domestic='$146,880,162', Foreign='$343,839,601'
# DEBUG:BoxOfficeScraper:Fila 21: Domestic='$174,340,174', Foreign='$260,653,009'
# DEBUG:BoxOfficeScraper:Fila 22: Domestic='$100,234,838', Foreign='$310,667,824'
# DEBUG:BoxOfficeScraper:Fila 23: Domestic='$80,227,895', Foreign='$329,003,712'
# DEBUG:BoxOfficeScraper:Fila 24: Domestic='$152,901,115', Foreign='$231,029,541'
# DEBUG:BoxOfficeScraper:Fila 25: Domestic='$114,581,250', Foreign='$266,964,596'
# DEBUG:BoxOfficeScraper:Fila 26: Domestic='$102,826,543', Foreign='$249,963,268'
# DEBUG:BoxOfficeScraper:Fila 27: Domestic='$44,898,413', Foreign='$301,219,864'
# DEBUG:BoxOfficeScraper:Fila 28: Domestic='-', Foreign='$334,530,869'
# DEBUG:BoxOfficeScraper:Fila 29: Domestic='$175,750,384', Foreign='$136,400,000'
# DEBUG:BoxOfficeScraper:Fila 30: Domestic='$838,959', Foreign='$306,753,468'
# DEBUG:BoxOfficeScraper:Fila 31: Domestic='$102,092,201', Foreign='$204,500,000'
# DEBUG:BoxOfficeScraper:Fila 32: Domestic='$132,422,809', Foreign='$173,514,909'
# DEBUG:BoxOfficeScraper:Fila 33: Domestic='$84,410,380', Foreign='$211,658,819'
# DEBUG:BoxOfficeScraper:Fila 34: Domestic='$138,291,365', Foreign='$140,162,993'
# DEBUG:BoxOfficeScraper:Fila 35: Domestic='$92,054,159', Foreign='$167,100,000'
# DEBUG:BoxOfficeScraper:Fila 36: Domestic='$362,657', Foreign='$257,380,359'
# DEBUG:BoxOfficeScraper:Fila 37: Domestic='$176,040,665', Foreign='$79,367,304'
# DEBUG:BoxOfficeScraper:Fila 38: Domestic='$20,186,659', Foreign='$233,971,731'
# DEBUG:BoxOfficeScraper:Fila 39: Domestic='$880,346', Foreign='$246,704,898'
# DEBUG:BoxOfficeScraper:Fila 40: Domestic='$74,262,031', Foreign='$166,629,732'
# DEBUG:BoxOfficeScraper:Fila 41: Domestic='$40,891,591', Foreign='$186,400,000'
# DEBUG:BoxOfficeScraper:Fila 42: Domestic='$1,891,956', Foreign='$225,199,334'
# DEBUG:BoxOfficeScraper:Fila 43: Domestic='$107,825,862', Foreign='$119,119,225'
# DEBUG:BoxOfficeScraper:Fila 44: Domestic='$41,189,488', Foreign='$184,684,740'
# DEBUG:BoxOfficeScraper:Fila 45: Domestic='$33,700,160', Foreign='$188,200,000'
# DEBUG:BoxOfficeScraper:Fila 46: Domestic='$86,089,513', Foreign='$131,687,133'
# DEBUG:BoxOfficeScraper:Fila 47: Domestic='$64,508,620', Foreign='$140,527,199'
# DEBUG:BoxOfficeScraper:Fila 48: Domestic='$45,020,282', Foreign='$152,163,264'
# DEBUG:BoxOfficeScraper:Fila 49: Domestic='$63,859,435', Foreign='$131,384,029'
# DEBUG:BoxOfficeScraper:Fila 50: Domestic='$104,897,530', Foreign='$80,502,815'
# DEBUG:BoxOfficeScraper:Fila 51: Domestic='$75,468,583', Foreign='$107,946,600'
# DEBUG:BoxOfficeScraper:Fila 52: Domestic='$104,029,443', Foreign='$76,583,737'
# DEBUG:BoxOfficeScraper:Fila 53: Domestic='$81,903,458', Foreign='$97,865,999'
# DEBUG:BoxOfficeScraper:Fila 54: Domestic='$58,060,186', Foreign='$119,796,565'
# DEBUG:BoxOfficeScraper:Fila 55: Domestic='$92,029,184', Foreign='$79,510,703'
# DEBUG:BoxOfficeScraper:Fila 56: Domestic='$40,563,557', Foreign='$129,238,364'
# DEBUG:BoxOfficeScraper:Fila 57: Domestic='$54,513,740', Foreign='$105,546,323'
# DEBUG:BoxOfficeScraper:Fila 58: Domestic='$471,575', Foreign='$152,422,689'
# DEBUG:BoxOfficeScraper:Fila 59: Domestic='$56,468,410', Foreign='$94,378,797'
# DEBUG:BoxOfficeScraper:Fila 60: Domestic='$39,175,066', Foreign='$110,000,000'
# DEBUG:BoxOfficeScraper:Fila 61: Domestic='$34,393,507', Foreign='$110,980,592'
# DEBUG:BoxOfficeScraper:Fila 62: Domestic='$85,364,450', Foreign='$56,972,790'
# DEBUG:BoxOfficeScraper:Fila 63: Domestic='$115,171,585', Foreign='$25,380,774'
# DEBUG:BoxOfficeScraper:Fila 64: Domestic='$51,342,000', Foreign='$83,524,593'
# DEBUG:BoxOfficeScraper:Fila 65: Domestic='$72,110,659', Foreign='$58,449,769'
# DEBUG:BoxOfficeScraper:Fila 66: Domestic='$55,683,845', Foreign='$69,795,421'
# DEBUG:BoxOfficeScraper:Fila 67: Domestic='$73,921,000', Foreign='$51,506,681'
# DEBUG:BoxOfficeScraper:Fila 68: Domestic='$59,281,555', Foreign='$64,400,000'
# DEBUG:BoxOfficeScraper:Fila 69: Domestic='-', Foreign='$122,026,260'
# DEBUG:BoxOfficeScraper:Fila 70: Domestic='$36,343,858', Foreign='$83,598,529'
# DEBUG:BoxOfficeScraper:Fila 71: Domestic='-', Foreign='$119,055,731'
# DEBUG:BoxOfficeScraper:Fila 72: Domestic='$50,701,325', Foreign='$62,529,753'
# DEBUG:BoxOfficeScraper:Fila 73: Domestic='$293,194', Foreign='$109,861,934'
# DEBUG:BoxOfficeScraper:Fila 74: Domestic='$1,908,823', Foreign='$107,475,149'
# DEBUG:BoxOfficeScraper:Fila 75: Domestic='-', Foreign='$103,818,506'
# DEBUG:BoxOfficeScraper:Fila 76: Domestic='$38,052,832', Foreign='$64,900,056'
# DEBUG:BoxOfficeScraper:Fila 77: Domestic='$30,234,022', Foreign='$70,307,784'
# DEBUG:BoxOfficeScraper:Fila 78: Domestic='$51,687,870', Foreign='$48,326,155'
# DEBUG:BoxOfficeScraper:Fila 79: Domestic='-', Foreign='$97,051,623'
# DEBUG:BoxOfficeScraper:Fila 80: Domestic='$57,386,418', Foreign='$39,555,697'
# DEBUG:BoxOfficeScraper:Fila 81: Domestic='$456,854', Foreign='$87,509,088'
# DEBUG:BoxOfficeScraper:Fila 82: Domestic='$5,560,921', Foreign='$81,759,079'
# DEBUG:BoxOfficeScraper:Fila 83: Domestic='$1,527,829', Foreign='$84,725,111'
# DEBUG:BoxOfficeScraper:Fila 84: Domestic='$45,018,541', Foreign='$40,200,000'
# DEBUG:BoxOfficeScraper:Fila 85: Domestic='$27,793,018', Foreign='$55,287,872'
# DEBUG:BoxOfficeScraper:Fila 86: Domestic='$485,728', Foreign='$82,400,450'
# DEBUG:BoxOfficeScraper:Fila 87: Domestic='-', Foreign='$79,226,860'
# DEBUG:BoxOfficeScraper:Fila 88: Domestic='$48,958,273', Foreign='$30,007,338'
# DEBUG:BoxOfficeScraper:Fila 89: Domestic='-', Foreign='$77,151,096'
# DEBUG:BoxOfficeScraper:Fila 90: Domestic='$28,370,522', Foreign='$40,372,963'
# DEBUG:BoxOfficeScraper:Fila 91: Domestic='$36,249,674', Foreign='$30,984,514'
# DEBUG:BoxOfficeScraper:Fila 92: Domestic='$22,245,070', Foreign='$44,313,395'
# DEBUG:BoxOfficeScraper:Fila 93: Domestic='-', Foreign='$64,236,772'
# DEBUG:BoxOfficeScraper:Fila 94: Domestic='-', Foreign='$63,144,805'
# DEBUG:BoxOfficeScraper:Fila 95: Domestic='$30,348,555', Foreign='$32,483,654'
# DEBUG:BoxOfficeScraper:Fila 96: Domestic='$40,852,824', Foreign='$21,960,150'
# DEBUG:BoxOfficeScraper:Fila 97: Domestic='$32,149,404', Foreign='$30,397,628'
# DEBUG:BoxOfficeScraper:Fila 98: Domestic='$44,307,191', Foreign='$17,880,338'
# DEBUG:BoxOfficeScraper:Fila 99: Domestic='$34,121,140', Foreign='$27,600,000'
# DEBUG:BoxOfficeScraper:Fila 100: Domestic='-', Foreign='$61,153,455'
# DEBUG:BoxOfficeScraper:Fila 101: Domestic='$45,852,178', Foreign='$14,993,533'
# DEBUG:BoxOfficeScraper:Fila 102: Domestic='-', Foreign='$60,600,361'
# DEBUG:BoxOfficeScraper:Fila 103: Domestic='$21,885,107', Foreign='$38,445,726'
# DEBUG:BoxOfficeScraper:Fila 104: Domestic='$28,780,744', Foreign='$30,503,271'
# DEBUG:BoxOfficeScraper:Fila 105: Domestic='$686,435', Foreign='$58,349,229'
# DEBUG:BoxOfficeScraper:Fila 106: Domestic='-', Foreign='$58,824,459'
# DEBUG:BoxOfficeScraper:Fila 107: Domestic='$186,135', Foreign='$57,442,157'
# DEBUG:BoxOfficeScraper:Fila 108: Domestic='$25,113,707', Foreign='$31,882,597'
# DEBUG:BoxOfficeScraper:Fila 109: Domestic='$42,873,127', Foreign='$13,538,458'
# DEBUG:BoxOfficeScraper:Fila 110: Domestic='$475,618', Foreign='$55,496,623'
# DEBUG:BoxOfficeScraper:Fila 111: Domestic='$44,922,302', Foreign='$10,746,396'
# DEBUG:BoxOfficeScraper:Fila 112: Domestic='$24,449,754', Foreign='$30,554,136'
# DEBUG:BoxOfficeScraper:Fila 113: Domestic='$30,014,539', Foreign='$23,924,758'
# DEBUG:BoxOfficeScraper:Fila 114: Domestic='-', Foreign='$53,834,292'
# DEBUG:BoxOfficeScraper:Fila 115: Domestic='-', Foreign='$52,946,454'
# DEBUG:BoxOfficeScraper:Fila 116: Domestic='-', Foreign='$48,825,526'
# DEBUG:BoxOfficeScraper:Fila 117: Domestic='$27,780,977', Foreign='$20,672,628'
# DEBUG:BoxOfficeScraper:Fila 118: Domestic='$47,319,572', Foreign='$1,014,360'
# DEBUG:BoxOfficeScraper:Fila 119: Domestic='-', Foreign='$48,065,601'
# DEBUG:BoxOfficeScraper:Fila 120: Domestic='$21,198,205', Foreign='$26,558,385'
# DEBUG:BoxOfficeScraper:Fila 121: Domestic='$22,105,643', Foreign='$25,241,640'
# DEBUG:BoxOfficeScraper:Fila 122: Domestic='$289,308', Foreign='$46,756,973'
# DEBUG:BoxOfficeScraper:Fila 123: Domestic='-', Foreign='$46,596,415'
# DEBUG:BoxOfficeScraper:Fila 124: Domestic='$124,187', Foreign='$46,139,050'
# DEBUG:BoxOfficeScraper:Fila 125: Domestic='$1,104,957', Foreign='$45,078,426'
# DEBUG:BoxOfficeScraper:Fila 126: Domestic='-', Foreign='$46,154,323'
# DEBUG:BoxOfficeScraper:Fila 127: Domestic='-', Foreign='$45,746,967'
# DEBUG:BoxOfficeScraper:Fila 128: Domestic='-', Foreign='$45,698,503'
# DEBUG:BoxOfficeScraper:Fila 129: Domestic='$16,883,115', Foreign='$28,275,139'
# DEBUG:BoxOfficeScraper:Fila 130: Domestic='-', Foreign='$44,560,421'
# DEBUG:BoxOfficeScraper:Fila 131: Domestic='$17,800,004', Foreign='$26,716,995'
# DEBUG:BoxOfficeScraper:Fila 132: Domestic='$33,800,859', Foreign='$10,179,962'
# DEBUG:BoxOfficeScraper:Fila 133: Domestic='$594,552', Foreign='$43,297,810'
# DEBUG:BoxOfficeScraper:Fila 134: Domestic='$6,700,035', Foreign='$36,384,025'
# DEBUG:BoxOfficeScraper:Fila 135: Domestic='$24,801,212', Foreign='$18,245,378'
# DEBUG:BoxOfficeScraper:Fila 136: Domestic='$6,735,118', Foreign='$35,452,547'
# DEBUG:BoxOfficeScraper:Fila 137: Domestic='$18,095,701', Foreign='$24,047,037'
# DEBUG:BoxOfficeScraper:Fila 138: Domestic='$2,418,404', Foreign='$39,560,027'
# DEBUG:BoxOfficeScraper:Fila 139: Domestic='$2,402,004', Foreign='$39,279,742'
# DEBUG:BoxOfficeScraper:Fila 140: Domestic='$32,187,017', Foreign='$9,000,000'
# DEBUG:BoxOfficeScraper:Fila 141: Domestic='$20,497,844', Foreign='$20,158,555'
# DEBUG:BoxOfficeScraper:Fila 142: Domestic='$20,738,724', Foreign='$19,402,248'
# DEBUG:BoxOfficeScraper:Fila 143: Domestic='$14,204', Foreign='$39,951,888'
# DEBUG:BoxOfficeScraper:Fila 144: Domestic='-', Foreign='$39,730,433'
# DEBUG:BoxOfficeScraper:Fila 145: Domestic='-', Foreign='$37,886,707'
# DEBUG:BoxOfficeScraper:Fila 146: Domestic='$2,401,722', Foreign='$35,150,422'
# DEBUG:BoxOfficeScraper:Fila 147: Domestic='$27,020,284', Foreign='$10,250,437'
# DEBUG:BoxOfficeScraper:Fila 148: Domestic='$216,556', Foreign='$36,580,260'
# DEBUG:BoxOfficeScraper:Fila 149: Domestic='$5,874', Foreign='$35,698,172'
# DEBUG:BoxOfficeScraper:Fila 150: Domestic='$29,819,114', Foreign='$5,849,903'
# DEBUG:BoxOfficeScraper:Fila 151: Domestic='$70,814', Foreign='$35,280,809'
# DEBUG:BoxOfficeScraper:Fila 152: Domestic='-', Foreign='$35,166,640'
# DEBUG:BoxOfficeScraper:Fila 153: Domestic='-', Foreign='$35,046,130'
# DEBUG:BoxOfficeScraper:Fila 154: Domestic='$30,971,040', Foreign='$3,843,062'
# DEBUG:BoxOfficeScraper:Fila 155: Domestic='-', Foreign='$34,598,750'
# DEBUG:BoxOfficeScraper:Fila 156: Domestic='$25,584,504', Foreign='$8,700,000'
# DEBUG:BoxOfficeScraper:Fila 157: Domestic='$277,019', Foreign='$33,470,987'
# DEBUG:BoxOfficeScraper:Fila 158: Domestic='$1,014,507', Foreign='$32,247,859'
# DEBUG:BoxOfficeScraper:Fila 159: Domestic='$20,783,704', Foreign='$12,133,649'
# DEBUG:BoxOfficeScraper:Fila 160: Domestic='-', Foreign='$32,841,493'
# DEBUG:BoxOfficeScraper:Fila 161: Domestic='-', Foreign='$32,783,733'
# DEBUG:BoxOfficeScraper:Fila 162: Domestic='-', Foreign='$32,433,588'
# DEBUG:BoxOfficeScraper:Fila 163: Domestic='-', Foreign='$31,191,910'
# DEBUG:BoxOfficeScraper:Fila 164: Domestic='$337,670', Foreign='$30,658,945'
# DEBUG:BoxOfficeScraper:Fila 165: Domestic='-', Foreign='$30,618,274'
# DEBUG:BoxOfficeScraper:Fila 166: Domestic='$108,970', Foreign='$29,840,282'
# DEBUG:BoxOfficeScraper:Fila 167: Domestic='$22,395,806', Foreign='$7,478,474'
# DEBUG:BoxOfficeScraper:Fila 168: Domestic='$21,120,616', Foreign='$8,700,000'
# DEBUG:BoxOfficeScraper:Fila 169: Domestic='$241,916', Foreign='$29,480,000'
# DEBUG:BoxOfficeScraper:Fila 170: Domestic='-', Foreign='$29,370,592'
# DEBUG:BoxOfficeScraper:Fila 171: Domestic='$1,522,976', Foreign='$27,799,363'
# DEBUG:BoxOfficeScraper:Fila 172: Domestic='-', Foreign='$28,952,258'
# DEBUG:BoxOfficeScraper:Fila 173: Domestic='$1,431,255', Foreign='$27,302,268'
# DEBUG:BoxOfficeScraper:Fila 174: Domestic='$252,895', Foreign='$28,392,553'
# DEBUG:BoxOfficeScraper:Fila 175: Domestic='-', Foreign='$27,975,429'
# DEBUG:BoxOfficeScraper:Fila 176: Domestic='$127,259', Foreign='$27,762,849'
# DEBUG:BoxOfficeScraper:Fila 177: Domestic='$10,709,995', Foreign='$17,159,134'
# DEBUG:BoxOfficeScraper:Fila 178: Domestic='$18,600,152', Foreign='$8,200,000'
# DEBUG:BoxOfficeScraper:Fila 179: Domestic='$8,106,986', Foreign='$18,513,016'
# DEBUG:BoxOfficeScraper:Fila 180: Domestic='$18,343,983', Foreign='$8,007,339'
# DEBUG:BoxOfficeScraper:Fila 181: Domestic='$46,796', Foreign='$26,242,582'
# DEBUG:BoxOfficeScraper:Fila 182: Domestic='$17,571,660', Foreign='$8,581,175'
# DEBUG:BoxOfficeScraper:Fila 183: Domestic='$1,993,259', Foreign='$24,141,050'
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3969012229/?ref_=bo_ydw_table_191
# DEBUG:BoxOfficeScraper:tconst encontrado: tt29519705
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr3547157253/?ref_=bo_ydw_table_192
# DEBUG:BoxOfficeScraper:tconst encontrado: tt33082302
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr879579909/?ref_=bo_ydw_table_193
# DEBUG:BoxOfficeScraper:tconst encontrado: tt14603848
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr611013381/?ref_=bo_ydw_table_194
# DEBUG:BoxOfficeScraper:tconst encontrado: tt28484935
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr1902990085/?ref_=bo_ydw_table_195
# DEBUG:BoxOfficeScraper:tconst encontrado: tt26530493
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr678253317/?ref_=bo_ydw_table_196
# DEBUG:BoxOfficeScraper:tconst encontrado: tt27510174
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr962810629/?ref_=bo_ydw_table_197
# DEBUG:BoxOfficeScraper:tconst encontrado: tt11821912
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2643874309/?ref_=bo_ydw_table_198
# DEBUG:BoxOfficeScraper:tconst encontrado: tt29454492
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr2959889157/?ref_=bo_ydw_table_199
# DEBUG:BoxOfficeScraper:tconst encontrado: tt33317136
# DEBUG:BoxOfficeScraper:Obteniendo tconst desde: https://www.boxofficemojo.com/releasegroup/gr1905545733/?ref_=bo_ydw_table_200
# DEBUG:BoxOfficeScraper:tconst encontrado: tt28151876
# 2025-01-05 20:06:40,799 - INFO - tconst encontrados: 200/200
# INFO:BoxOfficeScraper:tconst encontrados: 200/200
# 2025-01-05 20:06:40,813 - INFO - Vista previa de los datos recopilados:
# INFO:BoxOfficeScraper:Vista previa de los datos recopilados:
# DEBUG:BoxOfficeScraper:   Year  Rank                   Title  Worldwide_Gross  Domestic_Gross  \
# 0  2000     1  Mission: Impossible II        546388108       215409889
# 1  2000     2               Gladiator        460583960       187705427
# 2  2000     3               Cast Away        429632142       233632142
# 3  2000     4         What Women Want        374111707       182811707
# 4  2000     5                Dinosaur        349822765       137748063
#
#    International_Gross                                        Detail_Link  \
# 0            330978219  https://www.boxofficemojo.com/releasegroup/gr8...
# 1            272878533  https://www.boxofficemojo.com/releasegroup/gr2...
# 2            196000000  https://www.boxofficemojo.com/releasegroup/gr2...
# 3            191300000  https://www.boxofficemojo.com/releasegroup/gr1...
# 4            212074702  https://www.boxofficemojo.com/releasegroup/gr5...
#
#       tconst
# 0  tt0120755
# 1  tt0172495
# 2  tt0162222
# 3  tt0207201
# 4  tt0130623
# 2025-01-05 20:06:40,827 - INFO - Resumen de valores nulos:
# INFO:BoxOfficeScraper:Resumen de valores nulos:
# DEBUG:BoxOfficeScraper:Year                      0
# Rank                      0
# Title                     0
# Worldwide_Gross           0
# Domestic_Gross         1178
# International_Gross      42
# Detail_Link               0
# tconst                    0
# dtype: int64
# 2025-01-05 20:06:40,842 - INFO - Uploading data to BigQuery table: animum-dev-datawarehouse.BOMojo_staging_01.WorldwideBoxOffice_01...
# INFO:BoxOfficeScraper:Uploading data to BigQuery table: animum-dev-datawarehouse.BOMojo_staging_01.WorldwideBoxOffice_01...
# 2025-01-05 20:06:44,553 - INFO - Datos subidos exitosamente!
# INFO:BoxOfficeScraper:Datos subidos exitosamente!
# 2025-01-05 20:06:44,555 - INFO - Total de registros cargados: 5000
# INFO:BoxOfficeScraper:Total de registros cargados: 5000
